# %%
import pandas as pd

# %%
df=pd.read_csv("newfile.csv")

# %%
df
# Out:
#           Player  Duration  Matches  innings  NO  Runs  High_score    Ave  \
# 0    DG Bradman         20       52       80  10  6996         334  99.94
# 1   PHKD Mendis          3       12       21   2  1184         182  62.31
# 2      AC Voges          1       20       31   7  1485         269  61.87
# 3    RG Pollock          7       23       41   4  2256         274  60.97
# 4    GA Headley         24       22       40   4  2190         270  60.83
# ..           ...       ...      ...      ...  ..   ...         ...    ...
# 57   KD Walters         16       74      125  14  5357         250  48.26
# 58     GC Smith         12      117      205  13  9265         277  48.25
# 59  WH Ponsford         10       29       48   4  2122         266  48.22
# 60    SJ McCabe          8       39       62   5  2748         232  48.21
# 61   DR Jardine          6       22       33   6  1296         127  48.00
#
#     Balls_faced  Strike_rate  100  50   0    4s  6s Country  start_year  \
# ...

# %%
df.iloc[0]
# Out:
# Player         DG Bradman
# Duration                20
# Matches                 52
# innings                 80
# NO                      10
# Runs                  6996
# High_score             334
# Ave                  99.94
# Balls_faced           9800
# Strike_rate           58.6
# 100                     29
# 50                      13
# 0                        7
# 4s                     626
# 6s                       6
# Country                AUS
# start_year            1928
# end_year              1948
# Name: 0, dtype: object

# %%
import streamlit as st
player = st.selectbox("Select Player", df["Player"])
# Out:
# 2026-04-22 18:59:28.610 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-22 18:59:28.611 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-22 18:59:28.614 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-22 18:59:28.616 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-22 18:59:28.618 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# ...

# %%
players='DG Bradman '

pdata=df[df["Player"]==players]
stats=["100","50","6s","4s"]

# %%
chart_data=(pdata[stats].iloc[0].reset_index())

# %%
chart_data.columns = ["stat","Value"]

# %%
chart_data
# Out:
#   stat  Value
# 0  100     29
# 1   50     13
# 2   6s      6
# 3   4s    626

# %%
chart_data.plot(kind="bar",x="stat",y="Value")
# Out:
# <Axes: xlabel='stat'>

# %%
import plotly.express as px

# %%
fig=px.bar(
    chart_data,
    x="stat",
    y="Value"
)

# %%
fig

# %%
chart_data.plot(kind="bar",x="stat",y="Value")
# Out:
# <Axes: xlabel='stat'>
